# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# ### Dataset Contains 81 Columns
# ### SalePrice as our target Variable
# ### Id as a unique record

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# ## Feature Engineering
# #### We will perform following steps
# 1. Handling Missing Values
# ```
#    a. Numerical Features
#    b. Catrgorical Features
#    c. DateTime Features
# ```
# 2. Handling Special Cases
# 3. Standarize values to same range

# %% [markdown]
# ## Numerical Features

# %%
features_with_na=[feature for feature in data.columns if data[feature].isnull().sum()>1]
print('Number of NAN features {0}'.format(len(features_with_na)))
print(features_with_na)
for feature in features_with_na:
    print('{0} contains {1} missing values'.format(feature, data[feature].isnull().sum()))
# Out:
# Number of NAN features 18
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']
# LotFrontage contains 259 missing values
# Alley contains 1369 missing values
# MasVnrType contains 8 missing values
# MasVnrArea contains 8 missing values
# BsmtQual contains 37 missing values
# BsmtCond contains 37 missing values
# BsmtExposure contains 38 missing values
# BsmtFinType1 contains 37 missing values
# BsmtFinType2 contains 38 missing values
# FireplaceQu contains 690 missing values
# GarageType contains 81 missing values
# GarageYrBlt contains 81 missing values
# GarageFinish contains 81 missing values
# GarageQual contains 81 missing values
# GarageCond contains 81 missing values
# PoolQC contains 1453 missing values
# Fence contains 1179 missing values
# MiscFeature contains 1406 missing values

# %%
for feature in features_with_na:
    print('{0} contains {1} % of missing values'.format(feature, np.round(data[feature].isnull().mean() * 100, 2)))
# Out:
# LotFrontage contains 17.74 % of missing values
# Alley contains 93.77 % of missing values
# MasVnrType contains 0.55 % of missing values
# MasVnrArea contains 0.55 % of missing values
# BsmtQual contains 2.53 % of missing values
# BsmtCond contains 2.53 % of missing values
# BsmtExposure contains 2.6 % of missing values
# BsmtFinType1 contains 2.53 % of missing values
# BsmtFinType2 contains 2.6 % of missing values
# FireplaceQu contains 47.26 % of missing values
# GarageType contains 5.55 % of missing values
# GarageYrBlt contains 5.55 % of missing values
# GarageFinish contains 5.55 % of missing values
# GarageQual contains 5.55 % of missing values
# GarageCond contains 5.55 % of missing values
# PoolQC contains 99.52 % of missing values
# Fence contains 80.75 % of missing values
# MiscFeature contains 96.3 % of missing values

# %%
data[features_with_na].head(10)
# Out:
#    LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0         65.0   NaN    BrkFace       196.0       Gd       TA           No
# 1         80.0   NaN       None         0.0       Gd       TA           Gd
# 2         68.0   NaN    BrkFace       162.0       Gd       TA           Mn
# 3         60.0   NaN       None         0.0       TA       Gd           No
# 4         84.0   NaN    BrkFace       350.0       Gd       TA           Av
# 5         85.0   NaN       None         0.0       Gd       TA           No
# 6         75.0   NaN      Stone       186.0       Ex       TA           Av
# 7          NaN   NaN      Stone       240.0       Gd       TA           Mn
# 8         51.0   NaN       None         0.0       TA       TA           No
# 9         50.0   NaN       None         0.0       TA       TA           No
#
#   BsmtFinType1 BsmtFinType2 FireplaceQu GarageType  GarageYrBlt GarageFinish  \
# ...

# %%
data[features_with_na].tail(10)
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 1450         60.0   NaN       None         0.0       Gd       TA           No
# 1451         78.0   NaN      Stone       194.0       Gd       TA           No
# 1452         35.0   NaN    BrkFace        80.0       Gd       TA           Gd
# 1453         90.0   NaN       None         0.0       Gd       TA           No
# 1454         62.0  Pave       None         0.0       Gd       TA           No
# 1455         62.0   NaN       None         0.0       Gd       TA           No
# 1456         85.0   NaN      Stone       119.0       Gd       TA           No
# 1457         66.0   NaN       None         0.0       TA       Gd           No
# 1458         68.0   NaN       None         0.0       TA       TA           Mn
# 1459         75.0   NaN       None         0.0       TA       TA           No
#
#      BsmtFinType1 BsmtFinType2 FireplaceQu GarageType  GarageYrBlt  \
# ...

# %%
## Numerical variables containing missing values
numerical_with_nan=[feature for feature in data.columns if data[feature].isnull().sum()>1 and data[feature].dtypes!='O']

for feature in numerical_with_nan:
    print("{}: {}% missing value".format(feature,np.around(data[feature].isnull().mean() * 100,4)))
# Out:
# LotFrontage: 17.7397% missing value
# MasVnrArea: 0.5479% missing value
# GarageYrBlt: 5.5479% missing value

# %%
data[data['LotFrontage'].isnull()].head(20)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 7      8          60       RL          NaN    10382   Pave   NaN      IR1
# 12    13          20       RL          NaN    12968   Pave   NaN      IR2
# 14    15          20       RL          NaN    10920   Pave   NaN      IR1
# 16    17          20       RL          NaN    11241   Pave   NaN      IR1
# 24    25          20       RL          NaN     8246   Pave   NaN      IR1
# 31    32          20       RL          NaN     8544   Pave   NaN      IR1
# 42    43          85       RL          NaN     9180   Pave   NaN      IR1
# 43    44          20       RL          NaN     9200   Pave   NaN      IR1
# 50    51          60       RL          NaN    13869   Pave   NaN      IR2
# 64    65          60       RL          NaN     9375   Pave   NaN      Reg
# 66    67          20       RL          NaN    19900   Pave   NaN      Reg
# 76    77          20       RL          NaN     8475   Pave   NaN      IR1
# ...

# %%
data[data['GarageYrBlt'].isnull()].head(20)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39    40          90       RL         65.0     6040   Pave   NaN      Reg
# 48    49         190       RM         33.0     4456   Pave   NaN      Reg
# 78    79          90       RL         72.0    10778   Pave   NaN      Reg
# 88    89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 89    90          20       RL         60.0     8070   Pave   NaN      Reg
# 99   100          20       RL         77.0     9320   Pave   NaN      IR1
# 108  109          50       RM         85.0     8500   Pave   NaN      Reg
# 125  126         190       RM         60.0     6780   Pave   NaN      Reg
# 127  128          45       RM         55.0     4388   Pave   NaN      IR1
# 140  141          20       RL         70.0    10500   Pave   NaN      Reg
# 148  149          20       RL         63.0     7500   Pave   NaN      Reg
# 155  156          50       RL         60.0     9600   Pave   NaN      Reg
# ...

# %%
data[data['MasVnrArea'].isnull()].head(20)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL          NaN     7851   Pave   NaN      Reg
# 529    530          20       RL          NaN    32668   Pave   NaN      IR1
# 650    651          60       FV         65.0     8125   Pave   NaN      Reg
# 936    937          20       RL         67.0    10083   Pave   NaN      Reg
# 973    974          20       FV         95.0    11639   Pave   NaN      Reg
# 977    978         120       FV         35.0     4274   Pave  Pave      IR1
# 1243  1244          20       RL        107.0    13891   Pave   NaN      Reg
# 1278  1279          60       RL         75.0     9473   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# ...

# %%
## Handling Numerical Missing values
# data["LotFrontage"] = data.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
data["LotFrontage"] = data["LotFrontage"].median()
data['GarageYrBlt'] = data['GarageYrBlt'].fillna(0)
data['MasVnrArea']  =  data['MasVnrArea'].fillna(0)

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         69.0     8450   Pave   NaN      Reg
# 1   2          20       RL         69.0     9600   Pave   NaN      Reg
# 2   3          60       RL         69.0    11250   Pave   NaN      IR1
# 3   4          70       RL         69.0     9550   Pave   NaN      IR1
# 4   5          60       RL         69.0    14260   Pave   NaN      IR1
# 5   6          50       RL         69.0    14115   Pave   NaN      IR1
# 6   7          20       RL         69.0    10084   Pave   NaN      Reg
# 7   8          60       RL         69.0    10382   Pave   NaN      IR1
# 8   9          50       RM         69.0     6120   Pave   NaN      Reg
# 9  10         190       RL         69.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
## just to see the conversion of np.log to np.exp 
sale_original = np.array(data['SalePrice'])
sale_log      = np.log(sale_original)
sale_exp      = np.exp(sale_log)
print(sale_original[0:5])
print(sale_log[0:5])
print(np.floor(sale_exp)[0:5])
# print(sale_original - sale_exp)
# print(sale_exp.astype('int'))
# Out:
# [208500 181500 223500 140000 250000]
# [12.24769432 12.10901093 12.31716669 11.8493977  12.4292162 ]
# [208500. 181499. 223500. 139999. 249999.]

# %% [markdown]
# ## Log Transformation
# ### with EDA these features were skewed, so applying log transformation

# %%
skewed_features = ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in skewed_features:
    data[feature]=np.log(data[feature])

# %%
data[skewed_features].head(10)
# Out:
#    LotFrontage   LotArea  1stFlrSF  GrLivArea  SalePrice
# 0     4.234107  9.041922  6.752270   7.444249  12.247694
# 1     4.234107  9.169518  7.140453   7.140453  12.109011
# 2     4.234107  9.328123  6.824374   7.487734  12.317167
# 3     4.234107  9.164296  6.867974   7.448334  11.849398
# 4     4.234107  9.565214  7.043160   7.695303  12.429216
# 5     4.234107  9.554993  6.679599   7.216709  11.870600
# 6     4.234107  9.218705  7.434848   7.434848  12.634603
# 7     4.234107  9.247829  7.009409   7.644919  12.206073
# 8     4.234107  8.719317  6.929517   7.480992  11.774520
# 9     4.234107  8.911934  6.981935   6.981935  11.678440

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ### Handling Special Cases
# ``` After Performing Feature Engineering on Test Set ```
#
# ``` Utilities contains 2 missing values in Test Set, but no missing value in Training Set ```
#
# ``` Droping Utilities from Train Set as well ```

# %%
data = data.drop(['Utilities'], axis=1)

# %%
categorical_with_nan=[feature for feature in data.columns if data[feature].isnull().sum()>1 and data[feature].dtypes=='O']

for feature in categorical_with_nan:
    print("{}: {}% missing values".format(feature,np.round(data[feature].isnull().mean()*100,4)))
# Out:
# Alley: 93.7671% missing values
# MasVnrType: 0.5479% missing values
# BsmtQual: 2.5342% missing values
# BsmtCond: 2.5342% missing values
# BsmtExposure: 2.6027% missing values
# BsmtFinType1: 2.5342% missing values
# BsmtFinType2: 2.6027% missing values
# FireplaceQu: 47.2603% missing values
# GarageType: 5.5479% missing values
# GarageFinish: 5.5479% missing values
# GarageQual: 5.5479% missing values
# GarageCond: 5.5479% missing values
# PoolQC: 99.5205% missing values
# Fence: 80.7534% missing values
# MiscFeature: 96.3014% missing values

# %%
data_copy = data.copy()
data_copy[categorical_with_nan]=data_copy[categorical_with_nan].fillna('Missing')
data = data_copy

# %%
data[categorical_with_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
categorical_features = [feature for feature in data.columns if data[feature].dtype == 'O']
print(len(categorical_features))
print(categorical_features)
# Out:
# 42
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ### Handling Rare Categorical Variables
# ```if a cateogry occurs less then one percent then it can be set Rare_Cat```

# %%
for feature in categorical_features:
    print(data[feature].unique())
    temp=data.groupby(feature)['Id'].count()/len(data)
    print(temp)
    temp_df=temp[temp>0.01].index
    data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_Cat')
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# MSZoning
# C (all)    0.006849
# FV         0.044521
# RH         0.010959
# RL         0.788356
# RM         0.149315
# Name: Id, dtype: float64
# ['Pave' 'Grvl']
# Street
# Grvl    0.00411
# Pave    0.99589
# Name: Id, dtype: float64
# ['Missing' 'Grvl' 'Pave']
# Alley
# Grvl       0.034247
# Missing    0.937671
# Pave       0.028082
# Name: Id, dtype: float64
# ['Reg' 'IR1' 'IR2' 'IR3']
# LotShape
# IR1    0.331507
# IR2    0.028082
# IR3    0.006849
# Reg    0.633562
# Name: Id, dtype: float64
# ['Lvl' 'Bnk' 'Low' 'HLS']
# LandContour
# Bnk    0.043151
# HLS    0.034247
# Low    0.024658
# Lvl    0.897945
# Name: Id, dtype: float64
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# LotConfig
# Corner     0.180137
# CulDSac    0.064384
# FR2        0.032192
# FR3        0.002740
# Inside     0.720548
# Name: Id, dtype: float64
# ['Gtl' 'Mod' 'Sev']
# LandSlope
# Gtl    0.946575
# Mod    0.044521
# Sev    0.008904
# Name: Id, dtype: float64
# ...

# %%
data.head(30)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0    1          60       RL     4.234107  9.041922   Pave  Missing      Reg
# 1    2          20       RL     4.234107  9.169518   Pave  Missing      Reg
# 2    3          60       RL     4.234107  9.328123   Pave  Missing      IR1
# 3    4          70       RL     4.234107  9.164296   Pave  Missing      IR1
# 4    5          60       RL     4.234107  9.565214   Pave  Missing      IR1
# 5    6          50       RL     4.234107  9.554993   Pave  Missing      IR1
# 6    7          20       RL     4.234107  9.218705   Pave  Missing      Reg
# 7    8          60       RL     4.234107  9.247829   Pave  Missing      IR1
# 8    9          50       RM     4.234107  8.719317   Pave  Missing      Reg
# 9   10         190       RL     4.234107  8.911934   Pave  Missing      Reg
# 10  11          20       RL     4.234107  9.323669   Pave  Missing      Reg
# ...

# %%
for feature in categorical_features:
    print(feature)
    data[feature] = LabelEncoder().fit_transform(data[feature])
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition

# %%
data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         2     4.234107  9.041922       0      1         3
# 1   2          20         2     4.234107  9.169518       0      1         3
# 2   3          60         2     4.234107  9.328123       0      1         0
# 3   4          70         2     4.234107  9.164296       0      1         0
# 4   5          60         2     4.234107  9.565214       0      1         0
#
#    LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0            3          3          0             4           2           0
# 1            3          2          0            16           1           0
# 2            3          3          0             4           2           0
# 3            3          0          0             5           2           0
# 4            3          2          0            13           2           0
#
# ...

# %%
data.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         2     4.234107  9.041922       0      1         3
# 1   2          20         2     4.234107  9.169518       0      1         3
# 2   3          60         2     4.234107  9.328123       0      1         0
# 3   4          70         2     4.234107  9.164296       0      1         0
# 4   5          60         2     4.234107  9.565214       0      1         0
# 5   6          50         2     4.234107  9.554993       0      1         0
# 6   7          20         2     4.234107  9.218705       0      1         3
# 7   8          60         2     4.234107  9.247829       0      1         0
# 8   9          50         3     4.234107  8.719317       0      1         3
# 9  10         190         2     4.234107  8.911934       0      1         3
#
#    LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %% [markdown]
# ## DateTime Features

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    data[feature]=data['YrSold']-data[feature]

# %%
data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         2     4.234107  9.041922       0      1         3
# 1   2          20         2     4.234107  9.169518       0      1         3
# 2   3          60         2     4.234107  9.328123       0      1         0
# 3   4          70         2     4.234107  9.164296       0      1         0
# 4   5          60         2     4.234107  9.565214       0      1         0
#
#    LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0            3          3          0             4           2           0
# 1            3          2          0            16           1           0
# 2            3          3          0             4           2           0
# 3            3          0          0             5           2           0
# 4            3          2          0            13           2           0
#
# ...

# %%
data[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.to_csv('./Train/X_train.csv', index=False)

# %% [markdown]
# ## Feature Scaling

# %%
feature_scale=[feature for feature in data.columns if feature not in ['Id','SalePrice']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(data[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(data[feature_scale])
# Out:
# array([[0.23529412, 0.5       , 0.        , ..., 0.5       , 1.        ,
#         0.5       ],
#        [0.        , 0.5       , 0.        , ..., 0.25      , 1.        ,
#         0.5       ],
#        [0.23529412, 0.5       , 0.        , ..., 0.5       , 1.        ,
#         0.5       ],
#        ...,
#        [0.29411765, 0.5       , 0.        , ..., 1.        , 1.        ,
#         0.5       ],
#        [0.        , 0.5       , 0.        , ..., 1.        , 1.        ,
#         0.5       ],
#        [0.        , 0.5       , 0.        , ..., 0.5       , 1.        ,
#         0.5       ]])

# %%
# transform data features_scale and concat with Id SalePrice
data_scaled = pd.concat([data[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(data[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
data_scaled.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1  12.247694    0.235294       0.5          0.0  0.366344     0.0    0.5
# 1   2  12.109011    0.000000       0.5          0.0  0.391317     0.0    0.5
# 2   3  12.317167    0.235294       0.5          0.0  0.422359     0.0    0.5
# 3   4  11.849398    0.294118       0.5          0.0  0.390295     0.0    0.5
# 4   5  12.429216    0.235294       0.5          0.0  0.468761     0.0    0.5
#
#    LotShape  LandContour  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0       1.0          1.0       0.75        0.0      0.181818         0.4
# 1       1.0          1.0       0.50        0.0      0.727273         0.2
# 2       0.0          1.0       0.75        0.0      0.181818         0.4
# 3       0.0          1.0       0.00        0.0      0.227273         0.4
# 4       0.0          1.0       0.50        0.0      0.590909         0.4
#
# ...

# %%
data_scaled.to_csv('./Train/X_Scaled_train.csv',index=False)
